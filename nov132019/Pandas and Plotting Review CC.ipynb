# %% [markdown]
# # Pandas and Plotting Review

# %% [markdown]
# ## Import libraries and read in data

# %%
import pandas as pd
import numpy as np

# %%
# data = pd.read_csv('Concrete_Data.xls')

# %%
df = pd.read_excel('Concrete_Data.xls', index_col=None)
df
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %% [markdown]
# ## Display all the column names

# %%
df.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  \
# count                                1030.000000
# mean                                  281.165631
# std                                   104.507142
# min                                   102.000000
# 25%                                   192.375000
# 50%                                   272.900000
# 75%                                   350.000000
# max                                   540.000000
#
#        Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# count                                        1030.000000
# mean                                           73.895485
# std                                            86.279104
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            22.000000
# 75%                                           142.950000
# ...

# %%
df.columns
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %% [markdown]
# ## Preform a Groupby

# %%
df_gropup= df.groupby('Age (day)').mean()
df_gropup
# Out:
#            Cement (component 1)(kg in a m^3 mixture)  \
# Age (day)
# 1                                         442.500000
# 3                                         286.577910
# 7                                         312.923810
# 14                                        246.174839
# 28                                        265.443388
# 56                                        294.168571
# 90                                        284.140741
# 91                                        392.263636
# 100                                       220.900769
# 120                                       330.000000
# 180                                       331.334615
# 270                                       376.884615
# 360                                       267.533333
# 365                                       319.321429
#
#            Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# Age (day)
# 1                                                   0.000000
# ...

# %% [markdown]
# ## Create a Crosstab

# %%
df_crosstab=pd.crosstab(df['Age (day)'], df['Concrete compressive strength(MPa, megapascals) ']).T

# %%
df_crosstab
# Out:
# Age (day)                                         1    3    7    14   28   \
# Concrete compressive strength(MPa, megapascals)
# 2.331808                                            0    1    0    0    0
# 3.319827                                            0    1    0    0    0
# 4.565021                                            0    1    0    0    0
# 4.782206                                            0    1    0    0    0
# 4.827711                                            0    1    0    0    0
# ...                                               ...  ...  ...  ...  ...
# 79.400056                                           0    0    0    0    0
# 79.986111                                           0    0    0    0    1
# 80.199848                                           0    0    0    0    0
# 81.751169                                           0    0    0    0    1
# 82.599225                                           0    0    0    0    0
#
# ...

# %% [markdown]
# ## Create a heatmap with your crosstab

# %%
import seaborn as sns

sns.set()

ax = sns.heatmap(df_crosstab,cmap="YlGnBu", annot=True, cbar=False)

# %% [markdown]
# ## Create distribution plots for each feature

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Fit a regression model and extract feature importances

# %%
columns= list(df.columns)

for c in columns:
    sns.distplot(df[c])

# %% [markdown]
# ## Plot the 2 most important features, amnd the target with a 3d plot.

# %%
columns
# Out:
# ['Cement (component 1)(kg in a m^3 mixture)',
#  'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#  'Fly Ash (component 3)(kg in a m^3 mixture)',
#  'Water  (component 4)(kg in a m^3 mixture)',
#  'Superplasticizer (component 5)(kg in a m^3 mixture)',
#  'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#  'Fine Aggregate (component 7)(kg in a m^3 mixture)',
#  'Age (day)',
#  'Concrete compressive strength(MPa, megapascals) ']

# %%
target= 'Concrete compressive strength(MPa, megapascals) '
x = df.drop(target, axis= 1)
y = df[target]

# %%
x.shape
# Out:
# (1030, 8)

# %%
y.shape
# Out:
# (1030,)
